# %%
current_balance = 1000.00 # snake_case is the common way

# %%
current_balance
# Out:
# 1000.0

# %%
a = float(10) # float is a built-in function

# %%
a
# Out:
# 10.0

# %%
float = 10.0 # avoid use python key words

# %%
float
# Out:
# 10.0

# %%
b = float(20) # doesn't work becaus float is no a function anymore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 b = float(20)
#
# TypeError: 'float' object is not callable

# %%
del float # to delete the variable and go back the its state

# %%
b = float(20)

# %%
b
# Out:
# 20.0
