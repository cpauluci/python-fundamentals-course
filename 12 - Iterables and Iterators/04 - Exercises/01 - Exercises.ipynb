# %% [markdown]
# ### Solutions

# %% [markdown]
# #### Question 1

# %% [markdown]
# Given the following list:

# %%
l = [10, 'abc', 3.14, True]

# %% [markdown]
# Write code that prints out the index number and value at that index for every element of `l`.

# %%
l = [10, 'abc', 3.14, True]
for n in range(len(l)):
    print(f'[{n}]= {l[n]}')
# Out:
# [0]= 10
# [1]= abc
# [2]= 3.14
# [3]= True

# %%
for i, n in enumerate(l):
    print(f'[{i}]= {n}')
# Out:
# [0]= 10
# [1]= abc
# [2]= 3.14
# [3]= True

# %% [markdown]
# #### Question 2

# %% [markdown]
# We saw in this section how generator expressions can be more efficient, not only in terms os memory, but also in terms of computation time when not all values in the generator are iterated.

# %% [markdown]
# Create a generator expression that when iterated over will produce the integers from `1` to `10_000` raised to the power of `1`, `2`, `3`, etc.

# %% [markdown]
# So this generator should produce these results:

# %% [markdown]
# ```
# 1**1, 2**2, 3**3, 4**4, ...
# ```

# %% [markdown]
# Once you have created a generator expression to do this, time your results to create the generator and iterate through the first 5 elements of the generator.

# %% [markdown]
# Then, do the same thing, but using a list comprehension instead of a generator expression.

# %% [markdown]
# Hint: you should use the `perf_counter` apprioach we have seen a few times in previous lectures:
#
# ```
# from time import perf_counter
#
# start = perf_counter()
# # your code goes here
# end = perf_counter()
# print('elapsed:', end - start)
# ```

# %% [markdown]
# To make timings more accurate, you should time a loop that repeats your code at least 10 times.

# %%
from time import perf_counter

start = perf_counter()

for r in range(10):
    gen_power = (n ** n for n in range(1, 10_001))
    for i, power in enumerate(gen_power):
        print(power)
        if i > 3:
            break

end = perf_counter()
print('elapsed: ', end - start)
# Out:
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# elapsed:  0.009130643000389682

# %%
from time import perf_counter

start = perf_counter()

for _ in range(10):
    gen_power = (n ** n for n in range(1, 10_001))
    for _ in range(5):
        print(next(gen_power))

end = perf_counter()
print('elapsed: ', end - start)
# Out:
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# elapsed:  0.0007600460003232001

# %%
from time import perf_counter

start = perf_counter()

for r in range(10):
    gen_power = [n ** n for n in range(1, 10_001)]
    for i, power in enumerate(gen_power):
        print(power)
        if i > 3:
            break

end = perf_counter()
print('elapsed: ', end - start)
# Out:
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# elapsed:  66.85617326699958

# %%
from time import perf_counter

start = perf_counter()

l = [n ** n for n in range(1, 10_001)]
for _ in range(10):
    for value in l[:5]:
        print(value)

end = perf_counter()
print('elapsed: ', end - start)
# Out:
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# 1
# 4
# 27
# 256
# 3125
# elapsed:  6.694359779000479
